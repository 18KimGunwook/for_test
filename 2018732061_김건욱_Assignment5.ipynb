# %% [markdown]
# # 실습 Assignment 5
#
# 본인의 구글 드라이브를 Local로 하기위해 드라이브에 마운트를 해준다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# githup repository를 저장할 곳에 ```cd```명령어를 통해 이동한다.

# %%
cd /content/drive/MyDrive/Colab\ Notebooks/temp
# Out:
# /content/drive/MyDrive/Colab Notebooks/temp

# %% [markdown]
# ```!git clone```을 사용해 local에 repository를 저장한다.

# %%
# !git clone "https://github.com/18KimGunwook/2018732061_HW4.git"
# Out:
# Cloning into 'AI_Appl'...
# fatal: repository 'https://github.com/chorok-daddy/courses/tree/main/AI_Appl/' not found

# %% [markdown]
# 저장된 repository 파일로 이동한다.

# %%
cd 2018732061_HW4/
# Out:
# /content/drive/MyDrive/Colab Notebooks/temp/2018732061_HW4

# %% [markdown]
# push하기 위해 초기화를 한번 해준다.

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/temp/2018732061_HW4/.git/

# %% [markdown]
# 자신 githup 계정의 email과 사용자 이름을 등록한다.

# %%
# !git config --global user.email "gukim98@gmail.com"
# !git config --global user.name "18KimGunwook"

# %% [markdown]
# main으로 부터 branch_pr이라는 branch를 분기한다.

# %%
# !git checkout -b branch_pr
# Out:
# Branch 'branch_pr' set up to track remote branch 'branch_pr' from 'origin'.
# Switched to a new branch 'branch_pr'

# %% [markdown]
# 구글 드라이브에 Readme 파일을 적당히 수정한뒤
# branch_pr에 파일을 commit 한다.

# %%
# !git add .
# !git commit -m "README.md"
# Out:
# On branch branch_pr
# Your branch is up to date with 'origin/branch_pr'.
#
# nothing to commit, working tree clean

# %% [markdown]
# 토큰을 사용해 remote할 git repository에 연결한다.

# %%
# !git remote add origin https://18KimGunwook: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@github.com/18KimGunwook/2018732061_HW4.git

# %% [markdown]
# branch에 ```push``` 명령어를 통해 수정된 내용을 업데이트 한다.

# %%
# !git push -u origin branch_pr
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 294 bytes | 42.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/18KimGunwook/2018732061_HW4.git
#    f2c55dd..fef759c  branch_pr -> branch_pr
# Branch 'branch_pr' set up to track remote branch 'branch_pr' from 'origin'.

# %% [markdown]
# 팀원의 repository를 fork 한후 이를 내 local로 저장한다.

# %%
cd /content/drive/MyDrive/Colab\ Notebooks/temp
# !git clone "https://github.com/18KimGunwook/2020732079_HW4.git"
cd 2020732079_HW4/
# Out:
# Cloning into '2020732079_HW4'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %% [markdown]
# 내 학번이 적힌 branch를 분기한다.

# %%
# !git checkout -b branch_pr_2018732061
# Out:
# Switched to a new branch 'branch_pr_2018732061'

# %%
해당 branch에 적당히 수정한 Readme 파일을 commit 한다.

# %%
# !git add .
# !git commit -m "README.md"
# Out:
# [branch_pr_2018732061 ddad605] README.md
#  1 file changed, 3 insertions(+)

# %% [markdown]
# fork한 repository에 연결하기 전 이전의 remote를 해제해야 한다.

# %%
# !git remote remove origin

# %% [markdown]
# fork한 repository에 연결한다.

# %%
# !git remote add origin https://18KimGunwook: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@github.com/18KimGunwook/2020732079_HW4.git

# %% [markdown]
# 수정된 파일을 업데이트 한다.

# %%
# !git push -u origin branch_pr_2018732061
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 368 bytes | 92.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# remote:
# remote: Create a pull request for 'branch_pr_2018732061' on GitHub by visiting:
# remote:      https://github.com/18KimGunwook/2020732079_HW4/pull/new/branch_pr_2018732061
# remote:
# To https://github.com/18KimGunwook/2020732079_HW4.git
#  * [new branch]      branch_pr_2018732061 -> branch_pr_2018732061
# Branch 'branch_pr_2018732061' set up to track remote branch 'branch_pr_2018732061' from 'origin'.
