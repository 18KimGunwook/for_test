# %% [markdown]
# # 플랫폼(OS) 확인
# 이하의 코드는 본인의 랩탑의 정보들이 아닌
# google.colab 에서 제공되는 서버의 정보임을 인지

# %%
import platform  
"""하부 플랫폼의 식별 데이터에 대한 엑세스를 위한 라이브 러리"""
platform.platform() 
"""하부 플랫폼을 식별하는 가능한 많은 유용한 정보를 포함하는 단일 문자열을 반환"""
# Out:
# 'Linux-5.4.144+-x86_64-with-Ubuntu-18.04-bionic'

# %% [markdown]
# ##하드웨어 사양확인

# %%
# !cat /proc/cpuinfo """CPU의 정보 확인"""

# %%
# !cat /proc/meminfo """메모리 확인"""

# %%
# !df -h """마운트 된 디스크 사용량 확인"""

# %% [markdown]
# ## Python 버전 확인

# %%
# !python --version

# %% [markdown]
# ## 런타임 유형 변경 (런타임 >> 런타임유형변경)
# ##GPU 확인

# %%
# !nvidia-smi

# %% [markdown]
# ## Colab-Drive Mount
# 구글 드라이브에 마운트하는 코드

# %%
from google.colab import drive
drive.mount('/conten/drive')
