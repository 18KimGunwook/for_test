# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab\ Notebooks/2018732061_HW5/
# Out:
# /content/drive/MyDrive/Colab Notebooks/2018732061_HW5

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/2018732061_HW5/.git/

# %%
# !git config --global user.email "gukim98@gmail.com"
# !git config --global user.name "18KimGunwook"

# %%
# !git add .
# !git commit -m README.md
# Out:
# On branch branch01
# nothing to commit, working tree clean

# %%
# !git remote add origin https://18KimGunwook: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@github.com/18KimGunwook/2018732061_HW5.git
# Out:
# error: remote origin already exists.
